# %% [markdown]
# # Web Scrapping Assignment-4

# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. ScrapethedetailsofmostviewedvideosonYouTubefromWikipedia.
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(3)

# %%
#Creating empty list
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#Scraping data of video names
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
#Scraping data of artist name
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')

# %%
#Scraping data of upload dates
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')

# %%
#Scraping data of views
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[5]
# 2    3.                       "Johny Johny Yes Papa"[11]
# 3    4.                               "Shape of You"[12]
# 4    5.                              "See You Again"[14]
# 5    6.                                  "Bath Song"[19]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[20]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[21]
# 8    9.                                "Uptown Funk"[22]
# 9   10.                "Phonics Song with Two Words"[23]
# 10  11.                              "Gangnam Style"[24]
# 11  12.                             "Dame Tu Cosita"[29]
# 12  13.                                      "Sugar"[30]
# 13  14.                                      "Sorry"[31]
# 14  15.                                       "Roar"[32]
# 15  16.                             "Counting Stars"[33]
# 16  17.                          "Wheels on the Bus"[34]
# 17  18.                          "Thinking Out Loud"[35]
# 18  19.                                      "Faded"[36]
# 19  20.                             "Girls Like You"[37]
# 20  21.                                 "Dark Horse"[38]
# 21  22.                                   "Bailando"[39]
# 22  23.                                    "Lean On"[40]
# 23  24.                                 "Let Her Go"[41]
# 24  25.                                     "Axel F"[42]
# 25  26.                               "Shake It Off"[43]
# 26  27.                                    "Perfect"[44]
# 27  28.                                   "Mi Gente"[45]
# 28  29.           "Waka Waka (This Time for Africa)"[46]
# 29  30.                        "Baa Baa Black Sheep"[47]
#
#                                          Artist      Uploaded Date Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  9.85
# 1                                    Luis Fonsi   January 12, 2017  7.66
# 2                                   LooLoo Kids    October 8, 2016  6.01
# 3                                    Ed Sheeran   January 30, 2017  5.56
# 4                                   Wiz Khalifa      April 6, 2015  5.36
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018  4.74
# 6                                   Miroshka TV  February 27, 2018  4.54
# 7                                    Get Movies   January 31, 2012  4.47
# 8                                   Mark Ronson  November 19, 2014  4.39
# 9                                     ChuChu TV      March 6, 2014  4.35
# 10                                          Psy      July 15, 2012  4.28
# 11                                    El Chombo      April 5, 2018  3.76
# 12                                     Maroon 5   January 14, 2015  3.61
# 13                                Justin Bieber   October 22, 2015  3.49
# 14                                   Katy Perry  September 5, 2013  3.49
# 15                                  OneRepublic       May 31, 2013  3.46
# 16                   Cocomelon – Nursery Rhymes       May 24, 2018  3.41
# 17                                   Ed Sheeran    October 7, 2014  3.37
# 18                                  Alan Walker   December 3, 2015  3.20
# 19                                     Maroon 5       May 31, 2018  3.20
# 20                                   Katy Perry  February 20, 2014  3.19
# 21                             Enrique Iglesias     April 11, 2014  3.14
# 22                                  Major Lazer     March 22, 2015  3.13
# 23                                    Passenger      July 25, 2012  3.13
# 24                                   Crazy Frog      June 16, 2009  3.13
# 25                                 Taylor Swift    August 18, 2014  3.12
# 26                                   Ed Sheeran   November 9, 2017  3.04
# 27                                     J Balvin      June 29, 2017  3.01
# 28                                      Shakira       June 4, 2010  3.01
# 29                   Cocomelon – Nursery Rhymes      June 25, 2018  2.97

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(3)

# %%
#Getting url for international fixture and clicking on it
Options_btn = driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']").click()

Infix_btn = driver.find_element_by_xpath("//a[@class='navigation__link navigation__link--in-drop-down']").click()
time.sleep(5)

# %%
#Creating empty list
Match_title = []
Series = []
Place = []
Date = []
Time = []

# %%
#Scraping data of match title
for i in driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']"):
    Match_title.append(i.text)
    
#Scraping data of Place
for i in driver.find_elements_by_xpath("//p[@class='fixture__additional-info']//span"):
    Place.append(i.text)
    
#for scraping date and time we have go into each title    
#Scraping url for each match
mat_url = []
urls = driver.find_elements_by_xpath("//div[@class='js-list']//a")
for i in urls:
    mat_url.append(i.get_attribute("href"))
    
#Now scraping date, time and series
for i in mat_url:
    driver.get(i)
    time.sleep(8)
    
    
    #Scraping data of Series
    try:
        series = driver.find_element_by_xpath("/html/body/div[2]/div/div[2]/section[3]/div/ul/li[1]/span[2]")
        Series.append(series.text)
    except NoSuchElementException:
        Series.append('-')
        
    #Scraping data of dates
    try:
        date = driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']//strong")
        Date.append(date.text)
    except NoSuchElementException:
        Date.append('-')
        
    #Scraping data of time
    try:
        times = driver.find_element_by_xpath("//span[@class='mc-header-scorebox__ist-time']")
        Time.append(times.text)
    except NoSuchElementException:
        Time.append('-')

# %%
#DATA FRAMEING
BCCI=pd.DataFrame({})
BCCI['Match Title'] = Match_title
BCCI['Series'] = Series
BCCI['Place'] = Place
BCCI['Date'] = Date
BCCI['Time'] = Time

# %%
#Printing data frame
BCCI
# Out:
#    Match Title                          Series  \
# 0     1st Test  South Africa v India 2021/2022
# 1     2nd Test  South Africa v India 2021/2022
# 2     3rd Test  South Africa v India 2021/2022
# 3      1st ODI  South Africa v India 2021/2022
# 4     1st T20I  South Africa v India 2021/2022
# 5      2nd ODI  South Africa v India 2021/2022
# 6     2nd T20I  South Africa v India 2021/2022
# 7      3rd ODI  South Africa v India 2021/2022
# 8     3rd T20I  South Africa v India 2021/2022
# 9     4th T20I  South Africa v India 2021/2022
# 10     1st ODI        India v West Indies 2022
# 11     2nd ODI        India v West Indies 2022
# 12     3rd ODI        India v West Indies 2022
# 13    1st T20I        India v West Indies 2022
# 14    2nd T20I        India v West Indies 2022
# 15    3rd T20I        India v West Indies 2022
# 16    1st Test          India v Sri Lanka 2022
# 17    2nd Test          India v Sri Lanka 2022
# 18    1st T20I          India v Sri Lanka 2022
# 19    2nd T20I          India v Sri Lanka 2022
#
#                                                 Place                  Date  \
# 0                          Supersport Park, Centurion    Sunday 26 December
# 1                 New Wanderers Stadium, Johannesburg      Monday 3 January
# 2                                 Newlands, Cape Town    Tuesday 11 January
# 3                                  Boland Park, Paarl  Wednesday 19 January
# 4                                 Newlands, Cape Town  Wednesday 19 January
# 5                                  Boland Park, Paarl     Friday 21 January
# 6                                 Newlands, Cape Town     Friday 21 January
# 7                                 Newlands, Cape Town     Sunday 23 January
# 8                                  Boland Park, Paarl     Sunday 23 January
# 9                                  Boland Park, Paarl  Wednesday 26 January
# 10                   Narendra Modi Stadium, Ahmedabad     Sunday 6 February
# 11                     Sawai Mansingh Stadium, Jaipur  Wednesday 9 February
# 12                              Eden Gardens, Kolkata  Saturday 12 February
# 13                          Barabati Stadium, Cuttack   Tuesday 15 February
# 14                    ACA-VDCA Stadium, Visakhapatnam    Friday 18 February
# 15             Greenfield Stadium, Thiruvananthapuram    Sunday 20 February
# 16                   M.Chinnaswamy Stadium, Bangalore    Friday 25 February
# 17  Punjab Cricket Association Stadium, Mohali, Ch...      Saturday 5 March
# 18  Punjab Cricket Association Stadium, Mohali, Ch...       Sunday 13 March
# 19  Himachal Pradesh Cricket Association Stadium, ...      Tuesday 15 March
#
#          Time
# 0   13:30 IST
# 1   13:30 IST
# 2   14:00 IST
# 3   14:00 IST
# 4   19:30 IST
# 5   14:00 IST
# 6   19:30 IST
# 7   14:00 IST
# 8   19:30 IST
# 9   19:30 IST
# 10  13:00 IST
# 11  13:00 IST
# 12  13:00 IST
# 13  19:00 IST
# 14  19:00 IST
# 15  19:00 IST
# 16  09:30 IST
# 17  09:30 IST
# 18  19:00 IST
# 19  19:00 IST

# %% [markdown]
# # Q3.Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(3)

# %%
#Going to search bar and searching for selenium exception
ser_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
ser_bar.send_keys("selenium exception handling")
ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()
time.sleep(3)

# %%
#Url of selenium exception handling page
urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
page_url = urls.get_attribute("href")

driver.get(page_url)
time.sleep(5)

#Scraping data of names of exceptions
Name = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
    Name.append(i.text)
    
#Scraping data of descriptions of exceptions  
Description = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:
    Description.append(i.text)

# %%
#DATA FRAMEING
Guru=pd.DataFrame({})
Guru['Name of Exception'] = Name
Guru['Description of Exception'] = Description

# %%
#Printing data frame
Guru
# Out:
#                       Name of Exception  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                              Description of Exception
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# # Q4.Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) GSDP
#
# E) Share
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(3)

# %%
#Clicking on economy section
economy = driver.find_element_by_xpath("//div[@class='navbar']//div[2]//button").click()

urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)


#Scraping data of rank
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

    
# Scraping data of GSDP at current price (19-20)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price (18-19)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    GSDP_2.append(i.text)

    
#Scraping data of Share(18-19)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    GDP.append(i.text)

# %%
#DATA FRAMEING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['GSDP at current price (19-20)'] = GSDP_1
StatisticsTime['GSDP at current price (18-19)'] = GSDP_2
StatisticsTime['Share(18-19)'] = Share
StatisticsTime['GDP($ billion)'] = GDP

# %%
#Printing the data frame
StatisticsTime
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# 5     6                West Bengal                     1,253,832
# 6     7                  Rajasthan                     1,020,989
# 7     8             Andhra Pradesh                       972,782
# 8     9                  Telangana                       969,604
# 9    10             Madhya Pradesh                       906,672
# 10   11                     Kerala                             -
# 11   12                      Delhi                       856,112
# 12   13                    Haryana                       831,610
# 13   14                      Bihar                       611,804
# 14   15                     Punjab                       574,760
# 15   16                     Odisha                       521,275
# 16   17                      Assam                             -
# 17   18               Chhattisgarh                       329,180
# 18   19                  Jharkhand                       328,598
# 19   20                Uttarakhand                             -
# 20   21            Jammu & Kashmir                             -
# 21   22           Himachal Pradesh                       165,472
# 22   23                        Goa                        80,449
# 23   24                    Tripura                        55,984
# 24   25                 Chandigarh                             -
# 25   26                 Puducherry                        38,253
# 26   27                  Meghalaya                        36,572
# 27   28                     Sikkim                        32,496
# 28   29                    Manipur                        31,790
# 29   30                   Nagaland                             -
# 30   31          Arunachal Pradesh                             -
# 31   32                    Mizoram                        26,503
# 32   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share(18-19) GDP($ billion)
# 0                      2,632,792       13.94%        399.921
# 1                      1,630,208        8.63%        247.629
# 2                      1,584,764        8.39%        240.726
# 3                      1,502,899        7.96%        228.290
# 4                      1,493,127        7.91%        226.806
# 5                      1,089,898        5.77%        165.556
# 6                        942,586        4.99%        143.179
# 7                        862,957        4.57%        131.083
# 8                        861,031        4.56%        130.791
# 9                        809,592        4.29%        122.977
# 10                       781,653        4.14%        118.733
# 11                       774,870        4.10%        117.703
# 12                       734,163        3.89%        111.519
# 13                       530,363        2.81%         80.562
# 14                       526,376        2.79%         79.957
# 15                       487,805        2.58%         74.098
# 16                       315,881        1.67%         47.982
# 17                       304,063        1.61%         46.187
# 18                       297,204        1.57%         45.145
# 19                       245,895        1.30%         37.351
# 20                       155,956        0.83%         23.690
# 21                       153,845        0.81%         23.369
# 22                        73,170        0.39%         11.115
# 23                        49,845        0.26%          7.571
# 24                        42,114        0.22%          6.397
# 25                        34,433        0.18%          5.230
# 26                        33,481        0.18%          5.086
# 27                        28,723        0.15%          4.363
# 28                        27,870        0.15%          4.233
# 29                        27,283        0.14%          4.144
# 30                        24,603        0.13%          3.737
# 31                        22,287        0.12%          3.385
# 32                             -            -              -

# %% [markdown]
# # Q5.Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
#
# B) Repository description  C) Contributors count
#
# D) Language used

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
url="https://github.com/"   #passing url
driver=webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")
driver=webdriver.Chrome("chromedriver")
driver.get(url)
driver.set_window_size(800, 600)
time.sleep(3)
size = driver.get_window_size()
print("Window size: width = {}px, height = {}px.".format(size["width"], size["height"]))
time.sleep(2)
# Out:
# Window size: width = 800px, height = 600px.

# %%
#fetching required tags using xpath
menu_bar=driver.find_element_by_xpath("//button[@class='js-details-target btn-link d-lg-none mt-1']")
menu_bar.click()

explore=driver.find_elements_by_xpath("//summary[@class='HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block']")
for i in explore:
    if i.text=='Explore':   #using filters
        i.click()
        break
time.sleep(1)
trending=driver.find_elements_by_xpath("//li[@class='edge-item-fix']")
for j in trending:
    if j.text=='Trending':   #using filters
        j.click()
        break

name=[]   #empty list
for i in range(1):
    for j in driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']"):
        name.append(j.text)
description=[]  #empty list
for i in range(1):
    for j in driver.find_elements_by_xpath("//p[@class='col-9 color-text-secondary my-1 pr-4']"):
        description.append(j.text)
print('Name:',name)
print("\n","Description:",description)

# %% [markdown]
# # Q6: Scrape the details of top 100 songs on billboard.com. Url=https://www.billboard.com/. You have to find the following details:

# %% [markdown]
# A)Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#connect to the web driver
web_driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

#Get url in web driver first
url = 'https://www.billboard.com/'
web_driver.get(url)
#the url will open

# %%
#serch button click
charts_button = web_driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/header/div/ul/li[1]/a")
charts_button.click()

# %%
#serch button click
top100_button = web_driver.find_element_by_xpath("/html/body/main/div[2]/div/div[1]/a/div[2]/div[2]/div[1]")
top100_button.click()

# %%
#extract the tag having song name
name = web_driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
#to remove extra data other than output we required
Song_name = []
for i in name:
    Song_name.append(i.text)

#extract the tag having artist name
Artist = web_driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
#to remove extra data other than output we required
Artist_name = []
for i in Artist:
    Artist_name.append(i.text)

#extract the tag having last week rank
last_rank = web_driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
#to remove extra data other than output we required
Last_week_rank = []
for i in last_rank:
    Last_week_rank.append(i.text)

#extract the tag having last peak rank
peak_rank = web_driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
Peak_rank = []
for i in peak_rank:
    Peak_rank.append(i.text)

#extract the tag having last week rank
woc = web_driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
Weeks_on_chart = []
for i in woc:
    Weeks_on_chart.append(i.text)

# %%
# Make data frame of hot 100 from https://www.billboard.com/
Hot_100 = pd.DataFrame({})
Hot_100['Song_name']= Song_name
Hot_100['Artist_name'] = Artist_name
Hot_100['Last_week_rank'] = Last_week_rank 
Hot_100['Peak_rank'] = Peak_rank
Hot_100['Weeks_on_chart'] = Weeks_on_chart 
Hot_100
# Out:
# Empty DataFrame
# Columns: [Song_name, Artist_name, Last_week_rank, Peak_rank, Weeks_on_chart]
# Index: []

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/ You have to find the following details:

# %% [markdown]
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://www.naukri.com/"
driver.get(url)
time.sleep(3)

# %%
#Fetching urls for recruiter page
rec = driver.find_element_by_xpath("//a[@title='Search Recruiters']")
page_url = rec.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
#Fetching search button,bar xpath and clicking on it
search = driver.find_element_by_xpath("//div[@class='inpWrap']//input") 
search.send_keys("Data science ")           
but = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(4)

# %%
#Creating empty list
Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']")[:50]:
    Name.append(i.text)
time.sleep(5)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']")[:50]:
    Designation.append(i.text)
time.sleep(5)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]")[:50]:
    Company.append(i.text)
time.sleep(5)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")[:50]:
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(5)

#Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span")[:50]:
    Location.append(i.text)
time.sleep(5)

# %%
#DATA FRAMEING
Naukri=pd.DataFrame({})
Naukri['Name'] = Name
Naukri['Designation'] = Designation
Naukri['Company'] = Company
Naukri['Skills'] = Skills
Naukri['Location'] = Location

# %%
#Printing data frame
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# 18                             Sandhya Khandagale
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                         Avodha
# 31                                      Jayanth N
# 32                                    Priya Khare
# 33                                Dhruv Dev Dubey
# 34                                  Prateek Kumar
# 35                                    Amit Sharma
# 36                                          Kanan
# 37                           Shashikant Chaudhary
# 38                                           Brad
# 39                                   Rutuja Pawar
# 40                            Madhusudhan Sridhar
# 41                                    Ankit Sinha
# 42                                 Gaurav Chouhan
# 43                                   Rashi Kacker
# 44                                        Ashwini
# 45                                   Balaji Kolli
# 46                                 Rajani Nagaraj
# 47                                    ROHIT Kumar
# 48                                 Amir Chowdhury
# 49                                       SREEDHAR
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Team Lead
# 15                 Assistant Manager HR
# 16                           HR Manager
# 17  Senior Executive Talent Acquisition
# 18                         HR Recruiter
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30       Business Development Associate
# 31                      Project Manager
# 32                       Senior Manager
# 33             Company Recruitment Head
# 34                                 Head
# 35                           Consultant
# 36         senior technology instructor
# 37             HR Recruiter/HR Excutive
# 38        Manager, Technical Recruiting
# 39                  Technical Recruiter
# 40                      Erp Implementer
# 41                       Head Analytics
# 42              Chief Technical Officer
# 43                   Sr Product Manager
# 44             Director Global Delivery
# 45                           Co Founder
# 46                           HR Manager
# 47                            Architect
# 48                     Managing Partner
# 49               Recruitment Consultant
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                               SocialPrachar.com
# 15                   BIZ INFOTECNO PRIVATE LIMITED
# 16                                  BISP Solutions
# 17                           Bristlecone India Ltd
# 18                 Compumatrice Multimedia Pvt Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                              Nikitha Palaparthi
# 31        Dollarbird Information Services Pvt, Ltd
# 32                          Independent Consultant
# 33                                    Confidential
# 34                                         Trisect
# 35                                 ASCO consulting
# 36                                         NY INST
# 37  3D India Staffing Research &amp; Consulting...
# 38                                     O.C. Tanner
# 39                                   Demand Matrix
# 40                             MADHUSUDHAN SRIDHAR
# 41                                  Suntech Global
# 42                        Strategic Consulting Lab
# 43                            Impel Labs Pvt. Ltd.
# 44                                    MRP Advisers
# 45                   Saras Solutions India Pvt Ltd
# 46                                     WildJasmine
# 47                             LNT Private Limited
# 48                                     Granular.ai
# 49     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Social Media, digital media maketing, seo, smm...
# 15  React.js, Data Science, Java, Front End, Busin...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Big Data, Data Science, Artificial Intelligenc...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Ethical Hacking, Security Operations Center, S...
# 31  Data Analytics, Managed Services, Team Leading...
# 32  Data Science, Artificial Intelligence, analyti...
# 33  Server Administartion, Verilog, Vhdl, Digital ...
# 34  Java, Python, Angularjs, Software Testing, Mac...
# 35  Machine Learning, Artificial Intelligence, Dat...
# 36  C, C++, Artificial Intelligence, Python, Php, ...
# 37  Relationship Management, Retail Sales, Private...
# 38                 Data Science, Software Engineering
# 39  Data Science, Big Data Analytics, Digital Mark...
# 40                  Data Science, Recruitment, Salary
# 41  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 42  Software Development, Business Intelligence, B...
# 43                   Data Science, Node.js, Angularjs
# 44  Data Science, Media Marketing, Resource Planni...
# 45  Data Analysis, Learning, Data Science, Compute...
# 46  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 47  Software Development, Core Java, Unit Testing,...
# 48  Machine Learning, Data Science, Product Manage...
# 49  Data Science, Machine Learning, Big Data Analy...
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                 Priyanka Akiri
# 31                                     HR Manager
# 32                                      Hyderabad
# 33                                Kalpana Dumpala
# 34                               Executive Hiring
# 35                       Hyderabad / Secunderabad
# 36                                        Mubarak
# 37                                     Company HR
# 38                          Bengaluru / Bangalore
# 39                                 Kushal Rastogi
# 40                                     Company HR
# 41                                         Mumbai
# 42                             Mahesh Babu Channa
# 43                                   HR Team Lead
# 44                       Hyderabad / Secunderabad
# 45                                Sakshi Chhikara
# 46                           Assistant Manager HR
# 47                                     Chandigarh
# 48                                   Kapil Devang
# 49                                     HR Manager

# %% [markdown]
# # 8. Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/ You have to find the following details:

# %% [markdown]
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(3)

# %%
#Creating empty list
Book_name = []
Author = []
Volumes_sold = []
Publisher = []
Genre = []

# %%
#scraping data of book names
for i in driver.find_elements_by_xpath("//tbody//tr/td[2]"):
    Book_name.append(i.text)

    
#Scraping data of author names
for i in driver.find_elements_by_xpath("//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author.append(i.text)
    except NoSuchElementException:
        Author.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements_by_xpath("//tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements_by_xpath("//tbody/tr/td[5]"):
    Publisher.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//tbody/tr/td[6]"):
    Genre.append(i.text)

# %%
#DATA FRAMEING
Novel=pd.DataFrame({})
Novel['Book Name'] = Book_name
Novel['Author'] = Author
Novel['Volume sold'] = Volumes_sold
Novel['Publisher'] = Publisher
Novel['Genre'] = Genre

# %%
#Printing data frame
Novel
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:

# %% [markdown]
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(3)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
#Scraping data of Names
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

    
#Scraping data of Year span
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)

    
#Scraping data of Run time
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)

    
#Scraping data of Ratings
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)

    
#Scraping data of votes
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)

# %%
#DATA FRAMEING
IMDB=pd.DataFrame({})
IMDB['Name'] = Name
IMDB['Year Span'] = Year_span
IMDB['Genre'] = Genre
IMDB['Run Time'] = Run_time
IMDB['Ratings'] = Ratings
IMDB['Votes'] = Votes

# %%
#Printing data frame
IMDB
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,915,950
# 1    51 min     8.7    942,168
# 2    44 min     8.2    917,395
# 3    60 min     7.5    274,642
# 4    43 min     7.6    235,063
# ..      ...     ...        ...
# 95   42 min     7.5     46,830
# 96   50 min     7.8     57,604
# 97   42 min     8.1    181,623
# 98   45 min     7.1     37,973
# 99  572 min     8.6    215,559
#
# [100 rows x 6 columns]

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/ You have to find the following details:

# %% [markdown]
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year

# %%
#Activating the chrome browser
driver = webdriver.Chrome(r"/Users/mj/Downloads/chromedriver")

# %%
#getting the specified url
url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(3)

# %%
#fetching the required tags and looping it
click_btn=driver.find_element_by_xpath("//span[@class='whitetext']//b")
click_btn.click()
time.sleep(2)

name=[]  #empty list
try:                              #using try and except method
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a"):
            name.append(j.text)
except:
    name.append("-")

datatype=[]
try:
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p"):
            datatype.append(j.text)
except:
    datatype.append("-")

Task=[]
try:
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p"):
            Task.append(j.text)
except:
    Task.append("-")

attr_type=[]
try:
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p"):
            attr_type.append(j.text)
except:
    attr_type.append("-")
    
instances=[]
try:
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p"):
            instances.append(j.text)
except:
    instances.append("-")
    
attributes=[]
try:
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p"):
            attributes.append(j.text)
except:
    attributes.append("-")
    
year=[]
try:
    for i in range(1):
        for j in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p"):
            year.append(j.text)
except:
    year.append("-")

#printing outputs
print("Dataset name:",name)
print("\n","Data type:",datatype[1:])
print("\n","Task:",Task[1:])
print("\n","Attribute type:",attr_type[1:])
print("\n","No of instances:",instances[1:])
print("\n","No of attribute:",attributes[1:])
print("\n","Year:",year[1:])
driver.close()
# Out:
# Dataset name: ['Abalone', 'Adult', 'Annealing', 'Anonymous Microsoft Web Data', 'Arrhythmia', 'Artificial Characters', 'Audiology (Original)', 'Audiology (Standardized)', 'Auto MPG', 'Automobile', 'Badges', 'Balance Scale', 'Balloons', 'Breast Cancer', 'Breast Cancer Wisconsin (Original)', 'Breast Cancer Wisconsin (Prognostic)', 'Breast Cancer Wisconsin (Diagnostic)', 'Pittsburgh Bridges', 'Car Evaluation', 'Census Income', 'Chess (King-Rook vs. King-Knight)', 'Chess (King-Rook vs. King-Pawn)', 'Chess (King-Rook vs. King)', 'Chess (Domain Theories)', 'Bach Chorales', 'Connect-4', 'Credit Approval', 'Japanese Credit Screening', 'Computer Hardware', 'Contraceptive Method Choice', 'Covertype', 'Cylinder Bands', 'Dermatology', 'Diabetes', 'DGP2 - The Second Data Generation Program', 'Document Understanding', 'EBL Domain Theories', 'Echocardiogram', 'Ecoli', 'Flags', 'Function Finding', 'Glass Identification', "Haberman's Survival", 'Hayes-Roth', 'Heart Disease', 'Hepatitis', 'Horse Colic', 'ICU', 'Image Segmentation', 'Internet Advertisements', 'Ionosphere', 'Iris', 'ISOLET', 'Kinship', 'Labor Relations', 'LED Display Domain', 'Lenses', 'Letter Recognition', 'Liver Disorders', 'Logic Theorist', 'Lung Cancer', 'Lymphography', 'Mechanical Analysis', 'Meta-data', 'Mobile Robots', 'Molecular Biology (Promoter Gene Sequences)', 'Molecular Biology (Protein Secondary Structure)', 'Molecular Biology (Splice-junction Gene Sequences)', "MONK's Problems", 'Moral Reasoner', 'Multiple Features', 'Mushroom', 'Musk (Version 1)', 'Musk (Version 2)', 'Nursery', 'Othello Domain Theory', 'Page Blocks Classification', 'Optical Recognition of Handwritten Digits', 'Pen-Based Recognition of Handwritten Digits', 'Post-Operative Patient', 'Primary Tumor', 'Prodigy', 'Qualitative Structure Activity Relationships', 'Quadruped Mammals', 'Servo', 'Shuttle Landing Control', 'Solar Flare', 'Soybean (Large)', 'Soybean (Small)', 'Challenger USA Space Shuttle O-Ring', 'Low Resolution Spectrometer', 'Spambase', 'SPECT Heart', 'SPECTF Heart', 'Sponge', 'Statlog Project', 'Student Loan Relational', 'Teaching Assistant Evaluation', 'Tic-Tac-Toe Endgame', 'Thyroid Disease', 'Trains', 'University', 'Congressional Voting Records', 'Water Treatment Plant', 'Waveform Database Generator (Version 1)', 'Waveform Database Generator (Version 2)', 'Wine', 'Yeast', 'Zoo', 'Undocumented', 'Twenty Newsgroups', 'Australian Sign Language signs', 'Australian Sign Language signs (High Quality)', 'US Census Data (1990)', 'Census-Income (KDD)', 'Coil 1999 Competition Data', 'Corel Image Features', 'E. Coli Genes', 'EEG Database', 'El Nino', 'Entree Chicago Recommendation Data', 'CMU Face Images', 'Insurance Company Benchmark (COIL 2000)', 'Internet Usage Data', 'IPUMS Census Database', 'Japanese Vowels', 'KDD Cup 1998 Data', 'KDD Cup 1999 Data', 'M. Tuberculosis Genes', 'Movie', 'MSNBC.com Anonymous Web Data', 'NSF Research Award Abstracts 1990-2003', 'Pioneer-1 Mobile Robot Data', 'Pseudo Periodic Synthetic Time Series', 'Reuters-21578 Text Categorization Collection', 'Robot Execution Failures', 'Synthetic Control Chart Time Series', 'Syskill and Webert Web Page Ratings', 'UNIX User Data', 'Volcanoes on Venus - JARtool experiment', 'Statlog (Australian Credit Approval)', 'Statlog (German Credit Data)', 'Statlog (Heart)', 'Statlog (Landsat Satellite)', 'Statlog (Image Segmentation)', 'Statlog (Shuttle)', 'Statlog (Vehicle Silhouettes)', 'Connectionist Bench (Nettalk Corpus)', 'Connectionist Bench (Sonar, Mines vs. Rocks)', 'Connectionist Bench (Vowel Recognition - Deterding Data)', 'Economic Sanctions', 'Protein Data', 'Cloud', 'CalIt2 Building People Counts', 'Dodgers Loop Sensor', 'Poker Hand', 'MAGIC Gamma Telescope', 'UJI Pen Characters', 'Mammographic Mass', 'Forest Fires', 'Reuters Transcribed Subset', 'Bag of Words', 'Concrete Compressive Strength', 'Hill-Valley', 'Arcene', 'Dexter', 'Dorothea', 'Gisette', 'Madelon', 'Ozone Level Detection', 'Abscisic Acid Signaling Network', 'Par ...
#
#  Data type: ['Multivariate ', 'Multivariate ', 'Multivariate ', ' ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Univariate, Text ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Data-Generator ', 'Multivariate ', 'Multivariate ', 'Domain-Theory ', 'Univariate, Time-Series ', 'Multivariate, Spatial ', 'Multivariate ', 'Multivariate, Domain-Theory ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Time-Series ', 'Data-Generator ', ' ', ' ', 'Multivariate ', 'Multivariate ', 'Multivariate ', ' ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Time-Series ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Relational ', 'Multivariate ', 'Multivariate, Data-Generator ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Domain-Theory ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Domain-Theory ', 'Sequential, Domain-Theory ', 'Sequential ', 'Sequential, Domain-Theory ', 'Multivariate ', 'Domain-Theory ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Domain-Theory ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Domain-Theory ', 'Domain-Theory ', 'Multivariate, Data-Generator ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', ' ', 'Domain-Theory ', 'Multivariate ', 'Multivariate ', 'Multivariate, Domain-Theory ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Data-Generator ', 'Multivariate, Data-Generator ', 'Multivariate ', 'Multivariate ', 'Multivariate ', ' ', 'Text ', 'Multivariate, Time-Series ', 'Multivariate, Time-Series ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Relational ', 'Multivariate, Time-Series ', 'Spatio-temporal ', 'Transactional, Sequential ', 'Image ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Time-Series ', 'Multivariate ', 'Multivariate ', 'Relational ', 'Multivariate, Relational ', 'Sequential ', 'Text ', 'Multivariate, Time-Series ', 'Univariate, Time-Series ', 'Text ', 'Multivariate, Time-Series ', 'Time-Series ', 'Multivariate, Text ', 'Text, Sequential ', 'Image ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', ' ', 'Domain-Theory ', ' ', 'Multivariate ', 'Multivariate, Time-Series ', 'Multivariate, Time-Series ', 'Multivariate ', 'Multivariate ', 'Multivariate, Sequential ', 'Multivariate ', 'Multivariate ', 'Text ', 'Text ', 'Multivariate ', 'Sequential ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Sequential, Time-Series ', 'Multivariate ', 'Multivariate ', 'Time-Series ', 'Multivariate ', 'Multivariate, Sequential ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Sequential ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Time-Series ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Text ', 'Multivariate ', 'Multivariate ', 'Multivariate, Sequential ', 'Multivariate, Time-Series ', 'Univariate, Sequential, Time-Series ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate, Time-Series ', 'Text ', 'Domain-Theory ', 'Multivariate, Sequential ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Multivariate ', 'Time-Series ', 'Time-Series ', 'Multivariate, Text, Domain-Theory ', 'Time-Series, Domain-Theory ', 'Multivariate, Text, Domain-Theory ', 'Text ', 'Text ', 'Multivariate, Univariate,  ...
#
#  Task: ['Classification ', 'Classification ', 'Classification ', 'Recommender-Systems ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Regression ', 'Regression ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification, Regression ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Regression ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', ' ', ' ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Function-Learning ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Relational-Learning ', ' ', 'Classification ', 'Classification ', 'Classification ', ' ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', ' ', 'Classification ', 'Regression ', 'Classification ', 'Regression ', 'Classification ', 'Classification ', 'Regression ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Clustering ', ' ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Clustering ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', ' ', 'Classification ', 'Classification ', 'Clustering ', 'Classification ', ' ', ' ', ' ', ' ', ' ', 'Recommender-Systems ', 'Classification ', 'Regression, Description ', ' ', ' ', 'Classification ', 'Regression ', 'Classification ', ' ', ' ', ' ', ' ', ' ', ' ', 'Classification ', 'Classification ', 'Classification, Clustering ', 'Classification ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', ' ', 'Classification ', 'Classification ', ' ', ' ', ' ', ' ', ' ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Regression ', 'Classification ', 'Clustering ', 'Regression ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Classification ', 'Causal-Discovery ', 'Classification ', 'Classification, Clustering ', 'Classification ', 'Classification ', 'Classification ', 'Classification,