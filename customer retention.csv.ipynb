# %% [markdown]
# # importing necessary libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Case study

# %% [markdown]
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention on the basis of the Means End Chain theory (MEC) and Prospect theory. By hypothesising that a combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively, Structural equation model has been presented on the primary data collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction. By increasing the utilitarian value and hedonistic values derived by the customers, customer satisfaction and hence the customers repeat purchase intention can be increased significantly.

# %% [markdown]
# # importing dataset

# %%
df=pd.read_csv("/Applications/customer.csv")
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
#Lets chk the datatypes of all the columns
df.dtypes
# Out:
# 1Gender of respondent                                                    int64
# 2 How old are you?                                                       int64
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                               int64
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# # OrdinalEncoder

# %%
# As our dataset is imbalanced so we are doing ordinal encoding so that data become balanced
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 4                                      0.0
# ..                                     ...
# 264                                   10.0
# ...

# %% [markdown]
# # EDA

# %%
# lets chk the null values
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#lets look to the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("NULL VALUES")
plt.show()

# %%
#describing data
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %% [markdown]
# # Visualization of data

# %% [markdown]
# # Male or female who are more respondent to online shopping?

# %%
ax = sns.countplot(x="1Gender of respondent", data=df)
print(df["1Gender of respondent"].value_counts())
# represents 0-male and 1-female. It showing that females are higher in number
#from above observation females are 180 and males are 89
# Out:
# 1    180
# 0     89
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# # Which city do you shop online from?

# %%
#lets chk the value counts and visualization of column which city you mostly shop online
ax = sns.countplot(x="3 Which city do you shop online from?", data=df)
print(df["3 Which city do you shop online from?"].value_counts())
# so we can say from data that from delhi customers shop most online
# Out:
# 2.0     58
# 4.0     43
# 9.0     40
# 0.0     37
# 6.0     27
# 3.0     18
# 10.0    18
# 5.0     12
# 7.0      9
# 8.0      5
# 1.0      2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# # the Pin Code of where you shop online most?

# %%
ax = sns.countplot(x="4 What is the Pin Code of where you shop online from?", data=df)
print(df["4 What is the Pin Code of where you shop online from?"].value_counts())

#it seems that greater noida city  customers shop most online
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %% [markdown]
# # How many customers are shopping online?

# %%
ax = sns.countplot(x="5 Since How Long You are Shopping Online ?", data=df)
print(df["5 Since How Long You are Shopping Online ?"].value_counts())
#s among them showing that 98 are shopping online
# Out:
# 5    98
# 3    65
# 4    47
# 1    43
# 2    16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# # HOw many customers have made an online purchase in the past 1 year?

# %%
ax = sns.countplot(x="6 How many times you have made an online purchase in the past 1 year?", data=df)
print(df["6 How many times you have made an online purchase in the past 1 year?"].value_counts())

# It seems that 1 time in last past year are 114 for online purchase
# Out:
# 1    114
# 4     63
# 5     53
# 2     29
# 3     10
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# # How many customers access the internet while shopping on-line?

# %%
ax = sns.countplot(x="7 How do you access the internet while shopping on-line?", data=df)
print(df["7 How do you access the internet while shopping on-line?"].value_counts())

# It seems that mobile internet used by mostly 118 customers
# Out:
# 3    118
# 2     76
# 5     71
# 4      4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# # How many customers know  use to access the online shopping??

# %%
ax = sns.countplot(x="8 Which device do you use to access the online shopping?", data=df)
print(df["8 Which device do you use to access the online shopping?"].value_counts())
# It seems that smartphones are mostly used by customers for online shopping
# Out:
# 1    141
# 2     86
# 3     30
# 4     12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# # Displaying all columns using set_option

# %%
# displaying all 71 columns
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 4                                      0.0
# ..                                     ...
# 264                                   10.0
# ...

# %% [markdown]
# # How many customers know that content on the website must be easy to read and understand?

# %%
ax = sns.countplot(x="18 The content on the website must be easy to read and understand", data=df)
print(df["18 The content on the website must be easy to read and understand"].value_counts())

#It shows 164 customers strongly agree that content of website must be easy and understand
# Out:
# 5    164
# 4     80
# 1     18
# 3      7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# # How many customers says Complete information on listed seller and product?

# %%
ax = sns.countplot(x="20 Complete information on listed seller and product being offered is important for purchase decision.", data=df)
print(df["20 Complete information on listed seller and product being offered is important for purchase decision."].value_counts())

# It can be visualized that 101 customers are strongly agree by the decision
# Out:
# 4    101
# 5     87
# 3     52
# 2     18
# 1     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# # How many customers says relevant information on listed products must be stated clearly?

# %%
ax = sns.countplot(x="21 All relevant information on listed products must be stated clearly", data=df)
print(df["21 All relevant information on listed products must be stated clearly"].value_counts())

# It seen that 4 counts that is to be agree by the 132 customers that product info must be clear
# Out:
# 4    132
# 5    107
# 1     18
# 2     12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# # How many customers says Ease of navigation in website?

# %%
ax = sns.countplot(x="22 Ease of navigation in website", data=df)
print(df["22 Ease of navigation in website"].value_counts())

# It is seen that 141 customers are strongly agree that navigation in website is easy.
# Out:
# 5    141
# 4    105
# 1     18
# 2      5
# Name: 22 Ease of navigation in website, dtype: int64

# %% [markdown]
# # How many customers says for Loading and processing speed?

# %%
ax = sns.countplot(x="23 Loading and processing speed", data=df)
print(df["23 Loading and processing speed"].value_counts())
# It can be seen there are two category of customers some are agree 
#and some are strongly agree for loading and processing speed
# Out:
# 5    115
# 4    112
# 2     18
# 1     12
# 3     12
# Name: 23 Loading and processing speed, dtype: int64

# %% [markdown]
# # How many customers want user friendly interface of website?

# %%
ax = sns.countplot(x="24 User friendly Interface of the website", data=df)
print(df["24 User friendly Interface of the website"].value_counts())
# It can be visualize that maximum customers are strongly agree in category 5
# Out:
# 5    189
# 4     45
# 1     18
# 2     12
# 3      5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# # How many customers want Convenient Payment methods?

# %%
ax = sns.countplot(x="25 Convenient Payment methods", data=df)
print(df["25 Convenient Payment methods"].value_counts())
# maximum 159 cutomers are stronly agree for convenient payment methods
# Out:
# 5    159
# 4     80
# 2     30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# # How many customers have Trust that the online retail store will fulfill its part of the transaction at the stipulated time?

# %%
ax = sns.countplot(x="26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time", data=df)
print(df["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"].value_counts())

# maximum customers strongly agree to the trust online retail store will fulfill its part of the transaction at the stipulated time.
# Out:
# 5    141
# 4     86
# 2     30
# 3     12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# # How many customers says Empathy (readiness to assist with queries) towards the customers?

# %%
ax = sns.countplot(x="27 Empathy (readiness to assist with queries) towards the customers", data=df)
print(df["27 Empathy (readiness to assist with queries) towards the customers"].value_counts())

# It can be visualize that 194 almost maximum population strongly agree to readiness to assist with queries
# Out:
# 5    194
# 4     42
# 1     18
# 3     15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# # How many customers says Being able to guarantee the privacy of the customer?

# %%
ax = sns.countplot(x="28 Being able to guarantee the privacy of the customer", data=df)
print(df["28 Being able to guarantee the privacy of the customer"].value_counts())

# It can seen that 185 customers strongly agree to guarntee privacy of customers
# Out:
# 5    185
# 4     58
# 3     26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# # How many customers says that Responsiveness, availability of several communication channels?

# %%
ax = sns.countplot(x="29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)", data=df)
print(df["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"].value_counts())
# Out:
# 5    149
# 4     94
# 3     15
# 1     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# # How many customers says Online shopping gives monetary benefit and discounts?

# %%
ax = sns.countplot(x="30 Online shopping gives monetary benefit and discounts", data=df)
print(df["30 Online shopping gives monetary benefit and discounts"].value_counts())

# 105 customers are strongly agree that yes online shopping gives benefits and discounts
# Out:
# 5    105
# 4     85
# 3     50
# 1     18
# 2     11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %% [markdown]
# # HOw many customers says that Enjoyment is derived from shopping online?

# %%
ax = sns.countplot(x="31 Enjoyment is derived from shopping online", data=df)
print(df["31 Enjoyment is derived from shopping online"].value_counts())

# From data visualization it can be visualize that maximum around 86 are strongly agree 
#and around 75 are thinking indifferent about enjoyment from shopping online
# Out:
# 5    86
# 3    75
# 4    59
# 1    30
# 2    19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# # How many customers know that Shopping online is convenient and flexible?

# %%
ax = sns.countplot(x="32 Shopping online is convenient and flexible", data=df)
print(df["32 Shopping online is convenient and flexible"].value_counts())

# shopping online is more flexible and convenient agreed by 146
# Out:
# 5    146
# 4     78
# 3     33
# 2     12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %% [markdown]
# # How many customers believe Return and replacement policy of the e-tailer is important for purchase decision?

# %%
ax = sns.countplot(x="33 Return and replacement policy of the e-tailer is important for purchase decision", data=df)
print(df["33 Return and replacement policy of the e-tailer is important for purchase decision"].value_counts())

# maximum customers strongly agree that there should be return and replacement policy of e-tailor
# Out:
# 5    198
# 4     51
# 2     20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# # How many customers  Gaining access to loyalty programs is a benefit of shopping online?

# %%
ax = sns.countplot(x="34 Gaining access to loyalty programs is a benefit of shopping online", data=df)
print(df["34 Gaining access to loyalty programs is a benefit of shopping online"].value_counts())

# gaining access to loyality programs is a benefit of shopping online strongly agreed by maximum customers
#showing in count plot
# Out:
# 5    115
# 3     64
# 4     64
# 2     15
# 1     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %% [markdown]
# # How many customers Displaying quality Information on the website improves satisfaction of customers?

# %%
ax = sns.countplot(x="35 Displaying quality Information on the website improves satisfaction of customers", data=df)
print(df["35 Displaying quality Information on the website improves satisfaction of customers"].value_counts())

# showing count plot that customers strongly agree by quality of information improves satisfaction
# Out:
# 5    133
# 4     80
# 3     56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# # How many customers have User derive satisfaction while shopping on a good quality website or application?

# %%
ax = sns.countplot(x="36 User derive satisfaction while shopping on a good quality website or application", data=df)
print(df["36 User derive satisfaction while shopping on a good quality website or application"].value_counts())
# Out:
# 5    175
# 4     86
# 2      8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %% [markdown]
# # How many customers having Net Benefit derived from shopping online can lead to users satisfaction?

# %%
ax = sns.countplot(x="37 Net Benefit derived from shopping online can lead to users satisfaction", data=df)
print(df["37 Net Benefit derived from shopping online can lead to users satisfaction"].value_counts())

# count plot showing number of customers strongly agreed from shopping online lead to users satisfaction
# Out:
# 5    164
# 4     54
# 3     40
# 2     11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %% [markdown]
# # How many customers have believe  satisfaction cannot exist without trust?

# %%
ax = sns.countplot(x="38 User satisfaction cannot exist without trust", data=df)
print(df["38 User satisfaction cannot exist without trust"].value_counts())

# count plot showing that there are 2 categories of customers strongly agreed and agreed that user satisfaction cannot 
#exist without trust which is very important
# Out:
# 5    122
# 4    117
# 1     18
# 2      7
# 3      5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# # How many customers Offering a wide variety of listed product in several category?

# %%
ax = sns.countplot(x="39 Offering a wide variety of listed product in several category", data=df)
print(df["39 Offering a wide variety of listed product in several category"].value_counts())

# count plot showing maximum customers are strongly agreed to offering of wide listed products but closely related
# to agreed person also who are just agreed
# Out:
# 5    111
# 4     94
# 3     57
# 2      7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# # How many customers Provision of complete and relevant product information?

# %%
ax = sns.countplot(x="40 Provision of complete and relevant product information", data=df)
print(df["40 Provision of complete and relevant product information"].value_counts())
# Out:
# 5    135
# 4     98
# 3     31
# 2      5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# # How many customers have Monetary savings?

# %%
ax = sns.countplot(x="41 Monetary savings", data=df)
print(df["41 Monetary savings"].value_counts())

#countplot showing that maximum customers are strongly agreed to monetary savings is must
# Out:
# 5    148
# 4     75
# 2     31
# 3     15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# # How many cutomers Convenience of patronizing the online retailer?

# %%
ax = sns.countplot(x="42 The Convenience of patronizing the online retailer", data=df)
print(df["42 The Convenience of patronizing the online retailer"].value_counts())

# countplot showing that around 138 only agreed to the Convenience of patronizing the online retailer
# Out:
# 4    138
# 3     77
# 5     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %% [markdown]
# # How many customers Shopping on the website gives you the sense of adventure?

# %%
ax = sns.countplot(x="43 Shopping on the website gives you the sense of adventure", data=df)
print(df["43 Shopping on the website gives you the sense of adventure"].value_counts())

# countplot showing that 4 category of agreed customers feels that shooping on website gives sense of adventure
# Out:
# 4    101
# 3     59
# 5     54
# 2     50
# 1      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %% [markdown]
# # How many customers Shopping on your preferred e-tailer enhances your social status?

# %%
ax = sns.countplot(x="44 Shopping on your preferred e-tailer enhances your social status", data=df)
print(df["44 Shopping on your preferred e-tailer enhances your social status"].value_counts())

# count plot showing that maximum customers are indifferent towards enhances social status showing by 3
# Out:
# 3    100
# 4     59
# 5     48
# 1     33
# 2     29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %% [markdown]
# # How many customers feel gratification shopping on your favorite e-tailer?

# %%
ax = sns.countplot(x="45 You feel gratification shopping on your favorite e-tailer", data=df)
print(df["45 You feel gratification shopping on your favorite e-tailer"].value_counts())

#countplot showing again that maximum customers are indifferent shown by 3 that feeling gratification on fav e-tailor
#which doesn't affect to other customers
# Out:
# 3    101
# 5     65
# 4     63
# 2     22
# 1     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# # How much customers agreed for Shopping on the website helps you fulfill certain roles?

# %%
ax = sns.countplot(x="46 Shopping on the website helps you fulfill certain roles", data=df)
print(df["46 Shopping on the website helps you fulfill certain roles"].value_counts())


# count plot showing 2 categories of indifferent and agree customers are  equal i.e 3 and 4 showing
#shopping on website helps fulfill certain roles
# Out:
# 3    88
# 4    88
# 5    38
# 1    33
# 2    22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %% [markdown]
# # How much customers agreed for Getting value for money spent?

# %%
ax = sns.countplot(x="47 Getting value for money spent", data=df)
print(df["47 Getting value for money spent"].value_counts())


# count plot showing that 4 category is customers agreed to getting value for money spent
# Out:
# 4    149
# 5     82
# 3     38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# # Which website is Easy to use website or application?

# %%
ax = sns.countplot(x="Easy to use website or application", data=df)
print(df["Easy to use website or application"].value_counts())

# count plot showing that amazon.in is the website which is easy to use
# Out:
# 4.0    64
# 3.0    44
# 1.0    44
# 0.0    29
# 5.0    22
# 7.0    20
# 2.0    19
# 9.0    12
# 8.0     8
# 6.0     7
# Name: Easy to use website or application, dtype: int64

# %% [markdown]
# # Which online retailer have Visual appealing web-page layout?

# %%
ax = sns.countplot(x="Visual appealing web-page layout", data=df)
print(df["Visual appealing web-page layout"].value_counts())

#countplot showing that almost max customers like amazon.in for visual web page out
# Out:
# 1.0    87
# 0.0    44
# 3.0    36
# 6.0    20
# 9.0    15
# 5.0    15
# 8.0    15
# 2.0    14
# 7.0    12
# 4.0    11
# Name: Visual appealing web-page layout, dtype: int64

# %% [markdown]
# # Wild variety of product on offer

# %%
ax = sns.countplot(x="Wild variety of product on offer", data=df)
print(df["Wild variety of product on offer"].value_counts())

#countplot again showing that 130 customers like amazon.in website for wild variety of product on offer
# Out:
# 1.0    130
# 0.0     43
# 4.0     20
# 7.0     15
# 6.0     15
# 2.0     14
# 3.0     13
# 5.0     12
# 8.0      7
# Name: Wild variety of product on offer, dtype: int64

# %% [markdown]
# # Complete, relevant description information of products

# %%
ax = sns.countplot(x="Complete, relevant description information of products", data=df)
print(df["Complete, relevant description information of products"].value_counts())
#count plot showing 100 customers like amazon.in for relavant description of products
# Out:
# 1.0     100
# 0.0      43
# 4.0      24
# 7.0      20
# 2.0      15
# 5.0      15
# 3.0      14
# 10.0     12
# 9.0      11
# 8.0       8
# 6.0       7
# Name: Complete, relevant description information of products, dtype: int64

# %% [markdown]
# # Fast loading website speed of website and application

# %%
ax = sns.countplot(x="Fast loading website speed of website and application", data=df)
print(df["Fast loading website speed of website and application"].value_counts())

#count plot showing variations in customers views
# Out:
# 0.0    51
# 7.0    44
# 2.0    30
# 5.0    30
# 1.0    30
# 4.0    25
# 6.0    25
# 3.0    14
# 9.0    12
# 8.0     8
# Name: Fast loading website speed of website and application, dtype: int64

# %% [markdown]
# # Which online retailer have more Reliability of the website or application?

# %%
ax = sns.countplot(x="Reliability of the website or application", data=df)
print(df["Reliability of the website or application"].value_counts())

#countplot showing that customers reliabilty on amazon,myntra and paytm more comparision to others
# Out:
# 0.0    61
# 1.0    50
# 3.0    36
# 6.0    35
# 5.0    18
# 7.0    15
# 8.0    15
# 2.0    14
# 4.0    13
# 9.0    12
# Name: Reliability of the website or application, dtype: int64

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 4                                      0.0
# ..                                     ...
# 264                                   10.0
# ...

# %% [markdown]
# # Quickness to complete purchase

# %%
ax = sns.countplot(x="Quickness to complete purchase", data=df)
print(df["Quickness to complete purchase"].value_counts())

#count plot showing that customers quickly purschase from amazon.in
# Out:
# 0.0    66
# 3.0    47
# 1.0    37
# 2.0    30
# 8.0    25
# 5.0    20
# 4.0    15
# 6.0    15
# 7.0    14
# Name: Quickness to complete purchase, dtype: int64

# %% [markdown]
# # Which online retailer have Availability of several payment options?

# %%
ax = sns.countplot(x="Availability of several payment options", data=df)
print(df["Availability of several payment options"].value_counts())

# countplot showing that more availabilty options of payment find on amazon after that myntra will be there
# Out:
# 1.0     65
# 2.0     40
# 4.0     39
# 0.0     23
# 10.0    20
# 3.0     19
# 5.0     18
# 8.0     14
# 9.0     12
# 6.0     11
# 7.0      8
# Name: Availability of several payment options, dtype: int64

# %% [markdown]
# # Privacy of customers

# %%
ax = sns.countplot(x="Privacy of customers’ information", data=df)
print(df["Privacy of customers’ information"].value_counts())

# privacy of customer information maintained by amazon.in due to which customers rely on amazon more
# Out:
# 0.0     71
# 1.0     54
# 2.0     25
# 5.0     24
# 10.0    18
# 7.0     15
# 9.0     15
# 8.0     15
# 3.0     14
# 4.0     11
# 6.0      7
# Name: Privacy of customers’ information, dtype: int64

# %% [markdown]
# # Security of customer financial information

# %%
ax = sns.countplot(x="Security of customer financial information", data=df)
print(df["Security of customer financial information"].value_counts())

#countplot showing that customer's security financial info more maintained by amazon.in
# Out:
# 0.0     51
# 4.0     42
# 8.0     33
# 5.0     25
# 1.0     24
# 6.0     20
# 7.0     19
# 10.0    15
# 9.0     15
# 2.0     14
# 3.0     11
# Name: Security of customer financial information, dtype: int64

# %% [markdown]
# # Which retailer Perceived Trustworthiness?

# %%
ax = sns.countplot(x="Perceived Trustworthiness", data=df)
print(df["Perceived Trustworthiness"].value_counts())

# perceived trustworthiness maintained by amazon.in which again become customer trustworthy website
# Out:
# 0.0    76
# 5.0    36
# 6.0    35
# 1.0    31
# 7.0    27
# 2.0    25
# 8.0    15
# 4.0    13
# 3.0    11
# Name: Perceived Trustworthiness, dtype: int64

# %% [markdown]
# # Presence of online assistance through multi-channel

# %%
ax = sns.countplot(x="Presence of online assistance through multi-channel", data=df)
print(df["Presence of online assistance through multi-channel"].value_counts())

#countplot showing that amazon and myntra provides more presence of online assistance through multi-channel
# Out:
# 3.0    61
# 0.0    60
# 1.0    39
# 6.0    26
# 8.0    20
# 2.0    15
# 5.0    15
# 4.0    13
# 9.0    12
# 7.0     8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %% [markdown]
# # Longer time to get logged in

# %%
ax = sns.countplot(x="Longer time to get logged in (promotion, sales period)", data=df)
print(df["Longer time to get logged in (promotion, sales period)"].value_counts())

# countplot showing that amazon,filpkart and myntra provides linger time to get logged in
# Out:
# 0.0    57
# 8.0    38
# 1.0    38
# 7.0    35
# 2.0    29
# 9.0    25
# 5.0    15
# 6.0    13
# 3.0    11
# 4.0     8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %% [markdown]
# # Which retailer have longer delivery period?

# %%
ax = sns.countplot(x="Longer delivery period", data=df)
print(df["Longer delivery period"].value_counts())

#It can be visualize that paytm takes longer delievery period
# Out:
# 3.0    72
# 5.0    64
# 1.0    44
# 0.0    37
# 2.0    26
# 4.0    26
# Name: Longer delivery period, dtype: int64

# %% [markdown]
# # Which online retailer having more change in apaplication?

# %%
ax = sns.countplot(x="Change in website/Application design", data=df)
print(df["Change in website/Application design"].value_counts())

#It visualizes that amazon.in having more change in website believed by customers
# Out:
# 0.0    96
# 5.0    63
# 1.0    45
# 4.0    30
# 2.0    20
# 6.0     8
# 3.0     7
# Name: Change in website/Application design, dtype: int64

# %% [markdown]
# # which retailer have Limted mode of payment?

# %%
ax = sns.countplot(x="Limited mode of payment on most products (promotion, sales period)", data=df)
print(df["Limited mode of payment on most products (promotion, sales period)"].value_counts())

# can be visualize that customers seen that snapdeal having limited mode of payment
# Out:
# 7.0    87
# 0.0    62
# 3.0    31
# 1.0    29
# 5.0    25
# 6.0    15
# 2.0    13
# 4.0     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %% [markdown]
# # Longer page loading time

# %%
ax = sns.countplot(x="Longer page loading time (promotion, sales period)", data=df)
print(df["Longer page loading time (promotion, sales period)"].value_counts())

# Myntra and paytm having longer page loading time
# Out:
# 7.0     61
# 8.0     59
# 5.0     32
# 10.0    23
# 1.0     18
# 0.0     16
# 9.0     15
# 4.0     14
# 2.0     13
# 6.0     11
# 3.0      7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 4                                      0.0
# ..                                     ...
# 264                                   10.0
# ...

# %% [markdown]
# # Which online retailer have longer time in displaying

# %%
ax = sns.countplot(x="Longer time in displaying graphics and photos (promotion, sales period)", data=df)
print(df["Longer time in displaying graphics and photos (promotion, sales period)"].value_counts())

# countplot showing amazon.in Longer time in displaying graphics and photos (promotion, sales period)
# Out:
# 1.0    60
# 0.0    39
# 6.0    35
# 9.0    34
# 7.0    25
# 5.0    19
# 8.0    15
# 4.0    15
# 2.0    14
# 3.0    13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %% [markdown]
# # which website have Late declaration of price?

# %%
ax = sns.countplot(x="Late declaration of price (promotion, sales period)", data=df)
print(df["Late declaration of price (promotion, sales period)"].value_counts())

# It can be visualize that myntra.com declares price of promotions very late according to customers
# Out:
# 4.0    75
# 5.0    52
# 7.0    41
# 0.0    38
# 3.0    38
# 2.0    13
# 6.0     7
# 1.0     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
# # Frequent disruption in which website

# %%
ax = sns.countplot(x="Frequent disruption when moving from one page to another", data=df)
print(df["Frequent disruption when moving from one page to another"].value_counts())

# It visualize that amazon.in,mytra and snapdeal having frequently distrupt when moving from one page to another
# Out:
# 0.0    53
# 4.0    52
# 7.0    49
# 6.0    39
# 2.0    26
# 1.0    25
# 5.0    14
# 3.0    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %% [markdown]
# # Which Website is as efficient as before

# %%
ax = sns.countplot(x="Website is as efficient as before", data=df)
print(df["Website is as efficient as before"].value_counts())

# count plot showing that amazon.in is the website as efficient as before views by customers
# Out:
# 0.0    94
# 4.0    47
# 1.0    45
# 2.0    25
# 3.0    18
# 6.0    15
# 5.0    14
# 7.0    11
# Name: Website is as efficient as before, dtype: int64

# %% [markdown]
# # Best online retailer recommend to a friend

# %%
ax = sns.countplot(x="Which of the Indian online retailer would you recommend to a friend?", data=df)
print(df["Which of the Indian online retailer would you recommend to a friend?"].value_counts())

# customers belives and visualizes that amazon.in is the online and best retailer recommend to a friend
# Out:
# 0.0    79
# 1.0    62
# 6.0    39
# 3.0    30
# 5.0    20
# 2.0    15
# 4.0    13
# 7.0    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
#decribingthe dataset showing count,mean ,std deviations. standard deviations in some columns is very large means 
#skewness present in data.
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %%
#corr showing with all inputs 
df.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 3 Which city do you shop online from?                           -0.091867
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# ...                                                                   ...
# Longer delivery period                                          -0.052701
# Change in website/Application design                             0.154007
# Frequent disruption when moving from one page t...               0.260813
# Website is as efficient as before                               -0.047723
# Which of the Indian online retailer would you r...              -0.002005
#
#                                                     2 How old are you?   \
# ...

# %% [markdown]
# # Dist plot showing customers satisfaction in which area

# %%
#distplot showing plotting between all inputs data,some data are very undistrubuted and seems to be have variations
# and most of the plots clearly show that amazon got listed top by the customers followed by myntra and flipkart.
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %% [markdown]
# Customer retention is closely related to customer loyalty and is the opposite of customer defection  The marketing literature has traditionally focused on repeat purchase behavior of everyday products , but recent studies have increasingly focused on service customer experience and how a superior experience leads to customer retention.

# %% [markdown]
# # Relationsip Visualization Using Scatter Plot

# %%
#Relationship Visualizing

plt.figure(figsize = (20,45), facecolor = 'white')
plotnumber = 1

for column in df[0:20]:
    if plotnumber <= 20:
        ax = plt.subplot(10,2,plotnumber)
        sns.scatterplot(df[column],df['Which of the Indian online retailer would you recommend to a friend?'], color='g')
        plt.xlabel(column,fontsize=15)
        plt.ylabel('recommendation', fontsize=15)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# # Analysis from data as follows-

# %% [markdown]
# Amazon.in is having more privacy as compare to other web sites
# Amazon.in is having very secure financial services as compare to other websites
# Amazon.in is taking too much to time to log in as compare to other websites
# Myntra.com is declare very late price compare to other
# majority of customers are facing loading of pages in websites and that weebsites are myntra and amazon with peak of myntra.com
# Limited mode of payment on most products are having in snapdeal.com
# We can see paytm.com and snapdeal.com taking longer delivery period with peak of paytm.com
# change in design are more likely to see in amazin.in
# as we can see majority of customer are likely to prefer and suggest amazon and myntra with peak of amazon.in.

# %%
# skewness in data
df.skew()
# Out:
# 1Gender of respondent                                                  -0.723007
# 2 How old are you?                                                      0.063243
# 3 Which city do you shop online from?                                   0.313729
# 4 What is the Pin Code of where you shop online from?                   1.748322
# 5 Since How Long You are Shopping Online ?                             -0.554705
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64

# %% [markdown]
# # removing outliers:

# %%
#removing outliers:
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.42213639, 0.03843148, 0.78397694, ..., 1.40519246, 0.98469733,
#         1.52727829],
#        [0.70316744, 0.9013929 , 0.78397694, ..., 0.16163354, 0.52322768,
#         0.25533445],
#        [0.70316744, 0.9013929 , 0.15539334, ..., 0.94504654, 0.98469733,
#         1.10329701],
#        ...,
#        [0.70316744, 0.97825586, 1.41256055, ..., 1.33675303, 0.98469733,
#         1.01660938],
#        [0.70316744, 1.84121727, 1.73035746, ..., 0.55334004, 1.32265095,
#         1.01660938],
#        [0.70316744, 0.97825586, 0.46968514, ..., 1.40519246, 0.98469733,
#         1.01660938]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  0,   7,   7,   7,  13,  21,  21,  21,  27,  31,  38,  38,  38,
#         44,  52,  52,  52,  53,  53,  53,  59,  64,  64,  64,  65,  65,
#         65,  66,  70,  70,  70,  74,  82,  82,  82,  88, 101, 103, 103,
#        103, 110, 110, 110, 112, 113, 122, 124, 124, 124, 131, 131, 131,
#        133, 134, 143, 143, 143, 147, 151, 153, 156, 156, 156, 157, 157,
#        157, 158, 158, 158, 172, 182, 182, 182, 193, 196, 198, 198, 198,
#        203, 203, 203, 206, 206, 206, 207, 210, 214, 231, 231, 231, 232,
#        232, 232, 233, 233, 233, 245, 247, 250, 259, 263, 263, 263, 264,
#        264, 264]), array([32, 17, 21, 26, 28, 17, 21, 26, 28, 32, 17, 21, 26, 32, 17, 21, 26,
#        17, 21, 26, 32, 17, 21, 26, 17, 21, 26, 32, 17, 21, 26, 28, 10, 32,
#        35, 39, 28, 10, 32, 35, 17, 21, 26, 39, 32, 28, 10, 32, 35, 17, 21,
#        26, 39, 32, 17, 21, 26, 28, 28, 28, 17, 21, 26, 17, 21, 26, 17, 21,
#        26, 32, 10, 32, 35, 32, 39, 10, 32, 35, 10, 32, 35, 10, 32, 35, 39,
# ...

# %%
# new dataset with no outliers
df_new=df[(z<3).all(axis=1)]

# %%
df_new # new data set
# Out:
#      1Gender of respondent  2 How old are you?   \
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# 5                        1                    3
# ..                     ...                  ...
# 262                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 4                                      0.0
# 5                                      9.0
# ..                                     ...
# 262                                    0.0
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# After analyzing the data we can found that the important factor which afffects the online shopping. Customer satisfaction one of the most important factor in any platform and e-retail shoppers gives priority to it. We can see people more attracted towards the online shopping because of all this significant factors. The market of online shopping will automatically increase if we improve the Quality of services.
